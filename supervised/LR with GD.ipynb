# %% [markdown]
# # Logistic Regression with Gradient Descent

# %% [markdown]
# Let's use Iris data set for this example.

# %%
# import libraries
from __future__ import division
from sklearn import datasets
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='ticks', palette='Set2')

# %% [markdown]
# To simplify things we consider only two attributes and 2 classes in the data set.

# %%
data = datasets.load_iris()
X = data.data[:100, :2]
y = data.target[:100]
X_full = data.data[:100, :]

# %% [markdown]
# Let's plot the data

# %%
setosa = plt.scatter(X[:50,0], X[:50,1], c='b')
versicolor = plt.scatter(X[50:,0], X[50:,1], c='r')
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend((setosa, versicolor), ('Setosa', 'Versicolor'))
sns.despine()

# %% [markdown]
# ## Logistic function or Sigmoid function
# Let's see how a logistic function looks like.

# %%
x_values = np.linspace(-5, 5, 100)
y_vlaues = [1 / (1 + np.exp(-1 * x)) for x in x_values]
plt.plot(x_values, y_vlaues)
plt.axhline(0.5, c='b')
plt.axvline(0, c='b')
plt.xlabel("x_values")
plt.ylabel("y_labels")
sns.despine()
